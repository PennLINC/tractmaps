# %% [markdown]
# # Fetch and Parcellate Neurosynth Meta-Analyses (for 123 cognitive atlas terms)
# Author: Audrey Luo
# Edited by: Joëlle Bagautdinova
#
# This notebook is adapted from [Justine Hansen's tutorial]('https://github.com/netneurolab/ipn-summer-school/blob/main/lectures/2021-07-02/13-15/fetch_and_parcellate_neurosynth.ipynb') for fetching and parcellating Neurosynth terms. *Note that Neurosynth's package is now deprecated, so all of this code has been refactored using NiMARE!*
#
# The script does the following:
# 1. Fetch Neurosynth meta-analyses (association tests) for all available Cognitive Atlas concepts.
#     + Download raw Neurosynth data terms
#     + Convert Neurosynth database to NiMARE dataset file
#     + Run NiMARE's Multilevel kernel density analysis (MKDA) - Chi-square analysis to generate association z-value maps (i.e., reverse inference)
#
#
# 2. Concepts are parcellated according to:
#     + the 360-node Glasser (HCP-MMP)
#     + the 200-node Schaefer 2018 7-network
#
# This notebook will take approximately 25 minutes to run.

# %%
import warnings
warnings.filterwarnings('ignore', category = FutureWarning)
warnings.filterwarnings('ignore', category = RuntimeWarning)
import os
import numpy as np
import pandas as pd
from pathlib import Path
import requests
import gzip
import pickle
import json
import hcp_utils as hcp
import nibabel as nib
from nilearn.input_data import NiftiLabelsMasker
from nilearn._utils import check_niimg
from nilearn import datasets, image, plotting
from nilearn.datasets import fetch_atlas_schaefer_2018
from nimare.extract import download_abstracts, fetch_neurosynth
from nimare.io import convert_neurosynth_to_dataset
from nimare.correct import FDRCorrector
from nimare.dataset import Dataset
from nimare.meta.cbma.mkda import MKDAChi2
import Bio
from neuromaps import transforms
from neuromaps.parcellate import Parcellater
from neuromaps.datasets import fetch_fslr
from surfplot import Plot
import tm_parcellate
import sys
sys.path.append('..') # Move one directory up to access 'code' directory
from utils import tm_utils
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1

# %% [markdown]
# Some directory set-up and warning ignoring.

# %%
# this is where the raw and parcellated data will be stored
ns_dir = Path('/Users/joelleba/Data/tractmaps/neurosynth/raw/').resolve()
parc_dir = Path('/Users/joelleba/PennLINC/tractmaps/data/neurosynth_annotations/').resolve()

# create output directories
os.makedirs(ns_dir, exist_ok = True)
os.makedirs(parc_dir, exist_ok = True)

# we'll use association z-value maps generated using neurosynth-style NiMARE meta-analyses (these were also called 'specificity' in older NiMARE versions)
# can add 'z_desc-uniformity_level-voxel_corr-FDR_method-indep' plus more, if desired
# ma_images = ['z_desc-association_level-voxel_corr-FDR_method-indep'] # if you want FDR corrected maps (not used in this analysis, see below)
ma_images = ['z_desc-association']

# define email address (needed to download abstracts from neurosynth)
email_address = 'joelle.bagautdinova@pennmedicine.upenn.edu'

# %% [markdown]
# All the functions!

# %%
def get_cogatlas_concepts(url = None):
    """ 
    Fetches list of concepts from the Cognitive Atlas.
    
    Parameters
    ----------
    url : str
        URL to Cognitive Atlas API
    Returns
    -------
    concepts : set
        Unordered set of terms
    """

    if url is None:
        url = 'https://cognitiveatlas.org/api/v-alpha/concept'

    req = requests.get(url)
    req.raise_for_status()
    concepts = set([f.get('name') for f in json.loads(req.content)])

    return concepts

def run_meta_analyses(database, ma_images, use_features = None, outdir = None):
    """
    Runs NiMARE-style meta-analysis based on a NiMARE `Dataset` object.
    
    Parameters
    ----------
    database : NiMARE object of class `Dataset`.
        Storage container for a coordinate- and/or image-based meta-analytic dataset/database.
        Note: NiMARE database should be generated prior to running this function.
    use_features : list, optional
        List of features on which to run NS meta-analyses; if not supplied all
        terms in `features` will be used
    outdir : str or os.PathLike
        Path to output directory where derived files should be saved
    Returns
    -------
    generated : list of str
        List of filepaths to generated term meta-analysis directories
    """

    # check outdir
    if outdir is None:
        outdir = f'{ns_dir}/neurosynth'
    outdir = Path(outdir)
    
    # extract list of labels for which studies in Dataset have annotations
    all_features = set(database.get_labels()) 
    features = [f.replace("terms_abstract_tfidf__", "") for f in all_features] 
    
    # if we only want a subset of the features take the set intersection
    if use_features is not None:
        features = set(features) & set(use_features)
       
    # empty list to store meta-analytic outputs
    generated = [] 
    
    for word in sorted(features):
        msg = f'Running meta-analysis for term: {word}'
        print(msg, end = '\r', flush = True)

        # run meta-analysis and save specified outputs (only if they don't exist)
        path = outdir / word.replace(' ', '_')
        path.mkdir(exist_ok = True)
        if not all((path / f'{f}.nii.gz').exists() for f in ma_images):
            
            # get list of ids for each term of interest 
            ids = database.get_studies_by_label(f'terms_abstract_tfidf__{word}', 0.001)

            # Select studies with term of interest
            dset_sel = database.slice(ids) 

            # Select studies without term of interest
            no_term_ids = list(set(database.ids).difference(ids))
            dset_unsel = database.slice(no_term_ids)
            
            # Do Multilevel kernel density analysis (MKDA) - Chi-square analysis for coordinate-based meta-analysis
            # (NiMARE's estimator that matches Neurosynth's MetaAanalysis class)
            mkda = MKDAChi2(kernel__r = 10) # kernel radius of 10
            results = mkda.fit(dset_sel, dset_unsel) # fit MDKAChi2 model to studies with term of interest vs rest
            
            # FDR correction (voxel-level correction, i.e. the voxelwise z-statistics are adjusted)
#             corr = FDRCorrector(method = "indep", alpha = 0.05)
#             cres = corr.transform(results)
            
            # save out output maps specified in the ma_images list
            results.save_maps(path, names = ma_images)
#             cres.save_maps(path, names = ma_images)

        # store path to meta-analysis for the word
        generated.append(path)

    print(' ' * len(msg) + '\b' * len(msg), end = '', flush = True)

    return generated

 
def parcellate_meta(outputs, annots, fname, regions):
    '''
    Function takes outputs from previous analyses, parcellates the data based on anatomical labels, 
    stores the parcellated data in a DataFrame, and saves it to a CSV file.
    
    Parameters:
    -----------
        outputs : list
            A list containing paths to directories where output data from the meta-analyses are stored.
        annots : str or os.PathLike
            The path to a NIfTI file containing anatomical annotations or labels used for parcellation.
        fname : str or os.PathLike
            The filename (including path) where the parcellated data will be saved as a CSV file.
        regions : list of str
            A list of region names or labels used as the index for the resulting DataFrame.

    Returns:
    --------
        fname : str or os.PathLike
            The filename (including path) where the parcellated data was saved as a CSV file.
    '''
    # empty dataframe to hold our parcellated data
    data = pd.DataFrame(index = regions)
    
    # mask that will help extract data from meta-analytic niftis for our brain parcels
    mask = NiftiLabelsMasker(annots, resampling_target = 'data')

    for outdir in outputs:
        cdata = []
        nifti_file = outdir / 'z_desc-association.nii.gz'
        
        # convert path to string, then check that file is valid nifti image or array, 
        # apply mask to extract data corresponding to region labels with fit_transform, convert output to 1D array with squeeze
        cdata.append(mask.fit_transform(
            check_niimg(nifti_file.__str__(), atleast_4d = True)).squeeze())

        # store it as a new column in the dataframe (column name is the outdir,
        # and column values are the parcellated meta-analytic data by brain parcel)
        data = data.assign(**{outdir.name: np.hstack(cdata)})

    # save the parcellated meta-analysis data to csv
    data.to_csv(fname, sep = ',')
    
    # return the file path to the csv we just created
    return fname

# %% [markdown]
# ## 1. Fetch Neurosynth meta-analyses (association tests) for all available Cognitive Atlas concepts

# %% [markdown]
# ### Download raw NeuroSynth terms
#
# Neurosynth’s data files are stored at https://github.com/neurosynth/neurosynth-data.

# %%
# get neurosynth coordinates, metadata and vocabulary terms
files = fetch_neurosynth(
    data_dir = ns_dir,
    version = "7",
    overwrite = False,
    source = "abstract",
    vocab = "terms",
)
neurosynth_db = files[0]
# Out:
# INFO:nimare.extract.utils:Dataset found in /Users/joelleba/Data/tractmaps/neurosynth/raw/neurosynth
#
# INFO:nimare.extract.extract:Searching for any feature files matching the following criteria: [('source-abstract', 'vocab-terms', 'data-neurosynth', 'version-7')]
# Downloading data-neurosynth_version-7_coordinates.tsv.gz
# File exists and overwrite is False. Skipping.
# Downloading data-neurosynth_version-7_metadata.tsv.gz
# File exists and overwrite is False. Skipping.
# Downloading data-neurosynth_version-7_vocab-terms_source-abstract_type-tfidf_features.npz
# File exists and overwrite is False. Skipping.
# Downloading data-neurosynth_version-7_vocab-terms_vocabulary.txt
# File exists and overwrite is False. Skipping.

# %% [markdown]
# ### Convert Neurosynth database to NiMARE dataset file

# %%
# path to neurosynth dataset
output_file = os.path.join(ns_dir, 'neurosynth/neurosynth_dataset.pkl.gz')

# if absent, convert Neurosynth/NeuroQuery database files into NiMARE Dataset (take a little while)
if not os.path.exists(output_file):
    neurosynth_dset = convert_neurosynth_to_dataset(
        coordinates_file = neurosynth_db["coordinates"],
        metadata_file = neurosynth_db["metadata"],
        annotations_files = neurosynth_db["features"],
    )
    neurosynth_dset.save(output_file)
    print(neurosynth_dset)

#     neurosynth_dset = download_abstracts(neurosynth_dset, email_address)
#     neurosynth_dset.save(os.path.join(ns_dir, "neurosynth_dataset_with_abstracts.pkl.gz"))
else:
    print(f"{output_file} already exists; skipping code")
# Out:
# /Users/joelleba/Data/tractmaps/neurosynth/raw/neurosynth/neurosynth_dataset.pkl.gz already exists; skipping code

# %% [markdown]
# ### Run meta-analysis!

# %%
# with gzip.open(os.path.join(ns_dir, "neurosynth/neurosynth_dataset_with_abstracts.pkl.gz"), 'rb') as f:
with gzip.open(os.path.join(ns_dir, "neurosynth/neurosynth_dataset.pkl.gz"), 'rb') as f:
    neurosynth_dset = pickle.load(f)
    
# run NS meta-analyses on concepts from Cognitive Atlas (907 terms)
# when intersected with available terms from NeuroSynth (done in fct below), the total number of terms we'll analyze is N = 124
generated = run_meta_analyses(database = neurosynth_dset, 
                              ma_images = ma_images,
                              use_features = get_cogatlas_concepts()
                             )
# Out:
# Running meta-analysis for term: adaptation
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: addiction
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: anticipation
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: anxiety
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: arousal
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: association
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: attention
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: autobiographical memory
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: balance
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: belief
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: categorization
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: cognitive control
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: communication
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: competition
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: concept
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: consciousness
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: consolidation
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: context
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: coordination
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: decision
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: decision making
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: detection
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: discrimination
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: distraction
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: eating
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: efficiency
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: effort
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: emotion
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: emotion regulation
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: empathy
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: encoding
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: episodic memory
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: expectancy
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: expertise
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: extinction
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: face recognition
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: facial expression
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: familiarity
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: fear
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: fixation
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: focus
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: gaze
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: goal
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: hyperactivity
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: imagery
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: impulsivity
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: induction
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: inference
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: inhibition
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: insight
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: integration
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: intelligence
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: intention
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: interference
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: judgment
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: knowledge
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: language
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: language comprehension
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: learning
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: listening
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: localization
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: loss
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: maintenance
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: manipulation
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: meaning
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: memory
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: memory retrieval
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: mental imagery
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: monitoring
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: mood
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: morphology
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: motor control
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: movement
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: multisensory
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: naming
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: navigation
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: object recognition
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: pain
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: perception
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: planning
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: priming
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: psychosis
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: reading
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: reasoning
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: recall
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: recognition
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: rehearsal
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: reinforcement learning
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: response inhibition
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: response selection
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: retention
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: retrieval
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: reward anticipation
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: rhythm
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: risk
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: rule
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: salience
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: search
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: selective attention
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: semantic memory
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: sentence comprehension
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: skill
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: sleep
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: social cognition
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: spatial attention
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: speech perception
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: speech production
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: strategy
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: strength
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: stress
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: sustained attention
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: task difficulty
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: thought
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: timing
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: uncertainty
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: updating
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: utility
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: valence
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: verbal fluency
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: visual attention
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: visual perception
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: word recognition
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level
# Running meta-analysis for term: working memory
# WARNING:nimare.utils:Argument <class 'nimare.meta.kernel.MKDAKernel'> has already been initialized, so arguments will be ignored: r, memory, memory_level

# %% [markdown]
# ## 2. Parcellate Neurosynth maps
#
# Now that we have our neurosynth concept maps, the last step is to parcellate them so that we can use them in relation to the tract-to-region data. Note that we'll use the `z_desc-association.nii.gz` maps, as we're doing functional decoding and we care about similarity of the overall map, rather than statistical significance, so per Taylor Salo's recommendation we'll be using the unthresholded, uncorrected images.

# %% [markdown]
# ### Glasser parcellation (HCP-MMP)
#
# Tract-to-region data are in Glasser (HCP-MMP) 360 region parcellations, so let's first generate these. This can be done using the `glasserize()` function from `tm_parcellate`, which does the following:
#
# - takes a data dictionary input
# - loads Glasser parcellation (as flsr surface maps)
# - uses the `Neuromaps` `Parcellater` class, which takes care of transforming our volumetric MNI space Neurosynth concepts to fslr surface space (which is what the Glasser parcellation is in)
# - uses `fit_transform` to apply parcellation to neurosynth data (data are then automatically converted to fslr surface space)
# - parcellated neurosynth concepts are returned as a dictionary
# - Glasser labels and tract connections are then merged to it and this is saved as a csv

# %%
# Directory containing all the folders
root_dir = f'{ns_dir}/neurosynth'

# Create the cogatl_maps dictionary using dictionary comprehension
cogatl_maps = {
    term_name: {
        'annotation': ('cognitive atlas', term_name, 'MNI152'), # space (last term) will be used in glasserize() to parcellate data
        'map': os.path.join(root_dir, term_name, f'z_desc-association.nii.gz')
    }
    for term_name in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, term_name))
}

print(f'Loaded {len(cogatl_maps)} cognitive terms into the dictionary.')

# generate glasser parcellated neurosynth maps 
glasser_cogatl_maps = tm_parcellate.glasserize(cortical_maps = cogatl_maps, zscore = False) # z-scoring not applied as NS maps are already z-scored
print(f'Applied Glasser parcellation!')
# Out:
# Loaded 124 cognitive terms into the dictionary.
# Map: extinction
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: reading
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: psychosis
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: working_memory
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: categorization
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: intention
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: motor_control
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: addiction
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: attention
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: association
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: cognitive_control
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: listening
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: verbal_fluency
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: context
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: emotion_regulation
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: sustained_attention
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: speech_perception
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: imagery
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: coordination
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: memory
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: efficiency
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: manipulation
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: skill
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: anxiety
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: loss
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: face_recognition
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: intelligence
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: retention
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: sleep
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: effort
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: judgment
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: integration
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: sentence_comprehension
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: impulsivity
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: learning
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: multisensory
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: belief
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: speech_production
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: fear
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: consciousness
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: rehearsal
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: task_difficulty
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: expectancy
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: semantic_memory
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: facial_expression
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: planning
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: navigation
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: social_cognition
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: insight
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: balance
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: encoding
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: reward_anticipation
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: reinforcement_learning
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: language
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: meaning
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: reasoning
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: visual_attention
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: updating
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: focus
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: rule
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: recall
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: search
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: empathy
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: inhibition
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: timing
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: discrimination
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: action
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: retrieval
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: decision_making
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: knowledge
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: movement
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: concept
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: naming
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: memory_retrieval
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: episodic_memory
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: spatial_attention
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: response_inhibition
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: priming
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: visual_perception
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: salience
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: inference
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: rhythm
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: adaptation
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: language_comprehension
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: interference
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: maintenance
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: decision
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: morphology
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: recognition
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: word_recognition
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: valence
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: competition
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: communication
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: perception
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: gaze
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: familiarity
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: monitoring
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: induction
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: strength
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: mood
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: consolidation
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: thought
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: mental_imagery
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: selective_attention
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: object_recognition
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: fixation
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: risk
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: expertise
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: eating
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: hyperactivity
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: detection
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: uncertainty
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: response_selection
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: emotion
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: localization
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: arousal
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: anticipation
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: pain
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: goal
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: distraction
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: stress
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: autobiographical_memory
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: strategy
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Map: utility
# Original map shape: (91, 109, 91), parcellated shape: (360,)
# Applied Glasser parcellation!

# %%
# create output directory
out_dir = f'{parc_dir}/glasser/'
os.makedirs(out_dir, exist_ok = True)

# find terms in current list but not in reference list of cognitive atlas concepts
reference_ns_terms = pd.read_csv(f'{parc_dir}/neurosynth_categories.csv', header = None).values[:, 0] # from Bazinet paper, see link below
current_ns_terms = [term_name for term_name in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, term_name))]

# the extra term is 'timing'
print(f'Difference between the reference (Bazinet paper) and current list of cognitive atlas terms: {set(current_ns_terms) - set(reference_ns_terms)}')

# drop 'timing' from data
print('Dropping that term from analyses.')
# glasser_cogatl_maps.pop('timing_glasser')

# save 123 cognitive atlas terms dictionary for analyses
tm_utils.save_data(glasser_cogatl_maps, f'{out_dir}/glasser_neurosynth_123terms_dict.pickle')

# Transform cortical maps into dataframe
df_glasser_cogatl_maps = pd.DataFrame(glasser_cogatl_maps)
df_glasser_cogatl_maps['regionID'] = range(1, len(df_glasser_cogatl_maps) + 1)

# a little bit of cleaning
sorted_columns = sorted(df_glasser_cogatl_maps.columns.difference(['regionID'])) # Sort the cognitive terms columns alphabetically
df_glasser_cogatl_maps = pd.concat([df_glasser_cogatl_maps['regionID'], df_glasser_cogatl_maps[sorted_columns]], axis = 1) # reorder columns

# load df with tracts probs and glasser labels 
tracts_regs_ids = pd.read_csv(f'/Users/joelleba/PennLINC/tractmaps/data/tracts/glasser/glasser_tracts.csv')

# Merge tracts probability maps and cortical maps (rows are Glasser regions)
df_glasser_cogatl_maps_tracts = pd.merge(tracts_regs_ids, df_glasser_cogatl_maps, on = 'regionID')

# save to csv
df_glasser_cogatl_maps_tracts.to_csv(f'{out_dir}/glasser_tracts_neurosynth_123terms.csv', header = True, index = False)
# Out:
# Difference between the reference (Bazinet paper) and current list of cognitive atlas terms: {'timing'}
# Dropping that term from analyses.

# %% [markdown]
# ### Sanity check: visual comparison dense and parcellated map
#
# We'll do one final sanity check to see if the activation distribution for `action` in the dense neurosynth map is the same as the parcellated map we generated. It is, so we're done! The neurosynth maps are ready for analysis.

# %%
## plot the original map

# use neuromaps function to transform volumetric to surface space
orig_map_fslr = transforms.mni152_to_fslr(f'{ns_dir}/neurosynth/action/z_desc-association.nii.gz', '32k')
orig_map_lh, orig_map_rh = orig_map_fslr

surfaces = fetch_fslr() # from neuromaps
lh, rh = surfaces['inflated']
p = Plot(lh, rh, brightness = 0.9, zoom = 1.2) # brightness of the brain, from 0 (black) to 1 (white)
p.add_layer({'left': orig_map_lh, 'right': orig_map_rh}, cmap = 'viridis', cbar = True)
fig = p.build()
fig.show()


## plot the parcellated map
tm_utils.plot_parc_map(brain_map = glasser_cogatl_maps['action'], 
                              map_name = 'Action',
                              colors = 'viridis', 
                              mode = 'static', 
                              hemisphere = 'left')
tm_utils.plot_parc_map(brain_map = glasser_cogatl_maps['action'], 
                              map_name = 'Action',
                              colors = 'viridis', 
                              mode = 'static', 
                              hemisphere = 'right')
# Out:
# /var/folders/x3/55m85bd92ns7fklkwdt_m9cc0000gq/T/ipykernel_84159/1679392087.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Schaefer 200 parcellation
#
# This code from Justine Hansen's tutorial parcellates neurosynth maps into Schaefer 200. Note that it's easy (i.e., we don't need the `Parcellater` from Neuromaps) to parcellate to Schaefer since the atlas is already in MNI space just like the meta-analysis outputs.

# %%
# get parcellations that we'll use to parcellate data
schaefer = fetch_atlas_schaefer_2018(n_rois = 200, resolution_mm = 2)
labels = []
for i in range(len(schaefer['labels'])):
    labels.append(schaefer['labels'][i].decode("utf-8"))

# parcellate data and save to directory
parcellate_meta(generated, schaefer['maps'],
                f'{parc_dir}/schaefer200/schaefer2018_res-200_neurosynth_123terms.csv',
                regions = labels)
